# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from scipy.sparse import csr_matrix
import sparse_dot_topn.sparse_dot_topn as ct
import time

# %%
names =  pd.read_csv('sec__edgar_company_info.csv')
names.head()
# Out:
#    Line Number                        Company Name  Company CIK Key
# 0  1            !J INC                              1438823
# 1  2            #1 A LIFESAFER HOLDINGS, INC.       1509607
# 2  3            #1 ARIZONA DISCOUNT PROPERTIES LLC  1457512
# 3  4            #1 PAINTBALL CORP                   1433777
# 4  5            $ LLC                               1427189

# %% [markdown]
# N-Grams

# %%
def ngrams(string, n=3):
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

print('All 3-grams in "McDonalds":')
ngrams('McDonalds')
# Out:
# All 3-grams in "McDonalds":
# ['McD', 'cDo', 'Don', 'ona', 'nal', 'ald', 'lds']

# %%
company_names = names['Company Name']
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(company_names)

# %%
print(tf_idf_matrix[0])

# Check if this makes sense:

ngrams('!J INC')
# Out:
#   (0, 14549)	0.15757684989695478
#   (0, 812)	0.14545326532967898
#   (0, 14951)	0.517420185391102
#   (0, 1395)	0.828425757525274
# ['!J ', 'J I', ' IN', 'INC']

# %% [markdown]
# Cosine Similarity

# %%
def awesome_cossim_top(A, B, ntop, lower_bound=0):
    # force A and B as a CSR matrix.
    # If they have already been CSR, there is no overhead
    A = A.tocsr()
    B = B.tocsr()
    M, _ = A.shape
    _, N = B.shape
 
    idx_dtype = np.int32
 
    nnz_max = M*ntop
 
    indptr = np.zeros(M+1, dtype=idx_dtype)
    indices = np.zeros(nnz_max, dtype=idx_dtype)
    data = np.zeros(nnz_max, dtype=A.dtype)

    ct.sparse_dot_topn(
        M, N, np.asarray(A.indptr, dtype=idx_dtype),
        np.asarray(A.indices, dtype=idx_dtype),
        A.data,
        np.asarray(B.indptr, dtype=idx_dtype),
        np.asarray(B.indices, dtype=idx_dtype),
        B.data,
        ntop,
        lower_bound,
        indptr, indices, data)

    return csr_matrix((data,indices,indptr),shape=(M,N))

# %%
t1 = time.time()
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 10, 0.8)
t = time.time()-t1
print("SELFTIMED:", t)
# Out:
# SELFTIMED: 4064.3161499500275

# %%
def get_matches_df(sparse_matrix, name_vector, top=100):
    non_zeros = sparse_matrix.nonzero()
    
    sparserows = non_zeros[0]
    sparsecols = non_zeros[1]
    
    if top:
        nr_matches = top
    else:
        nr_matches = sparsecols.size
    
    left_side = np.empty([nr_matches], dtype=object)
    right_side = np.empty([nr_matches], dtype=object)
    similairity = np.zeros(nr_matches)
    
    for index in range(0, nr_matches):
        left_side[index] = name_vector[sparserows[index]]
        right_side[index] = name_vector[sparsecols[index]]
        similairity[index] = sparse_matrix.data[index]
    
    return pd.DataFrame({'left_side': left_side,
                          'right_side': right_side,
                           'similairity': similairity})

# %%
matches_df = get_matches_df(matches, company_names, top=100000)
matches_df = matches_df[matches_df['similairity'] < 0.99999] # Remove all exact matches
matches_df.sample(20)
# Out:
#                                                          left_side  \
# 65549  AMERICAN CENTURY INVESTMENT MANAGEMENT INC
# 69787  AMERICREDIT AUTOMOBILE RECEIVABLES TRUST 1999-C
# 15728  ACTIVANT RN HOLDINGS, LP
# 26568  ADVISORS DISCIPLINED TRUST 1334
# 10262  ABRAHAM & LONDON SECURITIES INC                         /BD
# 28486  ADVISORS DISCIPLINED TRUST 1509
# 35002  ADVISORS DISCIPLINED TRUST 472
# 69831  AMERICREDIT AUTOMOBILE RECEIVABLES TRUST 2000-A
# 46151  AGL LIFE ASSURANCE CO SEPARATE ACCOUNT VA 76
# 79436  ANGELLIST-OOF-FUND, A SERIES OF ANGELLIST FUNDS, LLC
# 94125  ARROWHEAD III LLC
# 37817  ADVISORS DISCIPLINED TRUST 72
# 98959  ASSET-BACKED CERTIFICATE SERIES 2003-2
# 30937  ADVISORS DISCIPLINED TRUST 1731
# 27933  ADVISORS DISCIPLINED TRUST 1458
# 28290  ADVISORS DISCIPLINED TRUST 1490
# 25053  ADVISORS DISCIPLINED TRUST 1196
# 19227  ADVANCED BIOMEDICAL TECHNOLOGIES INC.
# 22202  ADVENT LATIN AMERICAN PRIVATE EQUITY FUND V-F L.P.
# 88957  ARDEN REAL ESTATE PARTNERS II, L.P.
#
#                                                         right_side  \
# 65549  AMERICAN CENTURY INVESTMENT TRUST
# 69787  AMERICREDIT AUTOMOBILE RECEIVABLES TRUST 1999-D
# 15728  ACTIVANT RN CI HOLDINGS, LP
# 26568  ADVISORS DISCIPLINED TRUST 1333
# 10262  FIRST GRAHAM SECURITIES INC                             /BD
# 28486  ADVISORS DISCIPLINED TRUST 150
# 35002  ADVISORS DISCIPLINED TRUST 474
# 69831  AMERICREDIT AUTOMOBILE RECEIVABLES TRUST 2006-1
# 46151  AGL LIFE ASSURANCE CO SEPARATE ACCOUNT VA 73
# 79436  ANGELLIST-SINT-FUND, A SERIES OF ANGELLIST FUNDS, LLC
# 94125  ARROWHEAD II LLC
# 37817  ADVISORS DISCIPLINED TRUST 721
# 98959  HOME EQUITY LOAN ASSET-BACKED CERTIFICATES SERIES 2003-2
# 30937  ADVISORS DISCIPLINED TRUST 1730
# 27933  ADVISORS DISCIPLINED TRUST 1456
# 28290  ADVISORS DISCIPLINED TRUST 1494
# 25053  ADVISORS DISCIPLINED TRUST 1192
# 19227  ADVANCED MEDICAL TECHNOLOGIES LLC
# 22202  ADVENT LATIN AMERICAN PRIVATE EQUITY FUND III L P
# 88957  ARDEN REAL ESTATE PARTNERS II-Q, L.P.
#
#        similairity
# 65549  0.801774
# 69787  0.919151
# 15728  0.852126
# 26568  0.884002
# 10262  0.981131
# 28486  0.941103
# 35002  0.870395
# 69831  0.901690
# 46151  0.936436
# 79436  0.802388
# 94125  0.974536
# 37817  0.934933
# 98959  0.804767
# 30937  0.871904
# 27933  0.878904
# 28290  0.879775
# 25053  0.890859
# 19227  0.813801
# 22202  0.802576
# 88957  0.803276

# %%
matches_df.sort_values(['similairity'], ascending=False).head(10)
# Out:
#                                                          left_side  \
# 54674  ALLEN & CO INC                                          /BD
# 5861   A P SECURITIES INC                                      /BD
# 47650  AGS SECURITIES INC                                      /BD
# 99706  ASTOR SECURITIES INC                                    /BD
# 63516  AM CAPITAL LLC                                          /BD
# 41599  AE PARTNERS LLC                                         /BD
# 48229  AI SECURITIES INC                                       /BD
# 48230  AI SECURITIES INC                                       /BD
# 54147  ALL IN LLC                                              /BD
# 63517  AM CAPITAL LLC                                          /BD
#
#                                                         right_side  \
# 54674  MULLEN & CO INC                                         /BD
# 5861   J P SECURITIES INC                                      /BD
# 47650  CS SECURITIES INC                                       /BD
# 99706  MENTOR SECURITIES INC                                   /BD
# 63516  ML CAPITAL LLC                                          /BD
# 41599  LANE PARTNERS LLC                                       /BD
# 48229  CS SECURITIES INC                                       /BD
# 48230  USI SECURITIES INC                                      /BD
# 54147  WYN LLC                                                 /BD
# 63517  THOR CAPITAL LLC                                        /BD
#
#        similairity
# 54674  0.998930
# 5861   0.998636
# 47650  0.998415
# 99706  0.998364
# 63516  0.998340
# 41599  0.998318
# 48229  0.998301
# 48230  0.998287
# 54147  0.998228
# 63517  0.998185
